# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from IPython.display import Image
import pandas as pd
from datetime import date,datetime,timedelta
import time
import json

import re
import requests
import getpass
from logging import ERROR

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless') #local_non_use
chrome_options.add_argument('--no-sandbox') #local_non_use
chrome_options.add_argument('--disable-dev-shm-usage') #local_non_use

# Set the locale
#chrome_locale = 'locale-of-choice'
#chrome_options = webdriver.ChromeOptions()
#chrome_options.add_argument("--lang={}".format(chrome_locale))
# End - Set the locale

chrome_options.add_argument("accept-language=en-th")

# %%
driver = webdriver.Chrome('chromedriver', chrome_options=chrome_options)

driver.maximize_window()

url_main = 'https://www.lazada.co.th/products/edifier-w220t-tws-53-24-qcc3056-ip54-1-i3640204764-s15011736651.html?clickTrackInfo=query%253A%253Bnid%253A3640204764%253Bsrc%253AlazadaInShopSrp%253Brn%253A51785ceae4c1bbd0d5c31bd85e571322%253Bregion%253Ath%253Bsku%253A3640204764_TH%253Bprice%253A1799.00%253Bclient%253Adesktop%253Bsupplier_id%253A100192950246%253Basc_category_id%253A7145%253Bitem_id%253A3640204764%253Bsku_id%253A15011736651%253Bshop_id%253A2327921&freeshipping=1&fs_ab=1&fuse_fs=1&mp=1&source=search&spm=a2o4m.seller.list.i30.1581337da0aiXq'
driver.get(url_main)
time.sleep(10)

# obtain browser height and width
w = driver.execute_script('return document.body.parentNode.scrollWidth')
h = driver.execute_script('return document.body.parentNode.scrollHeight')
# set to new window size
driver.set_window_size(w, h)

''' try:
    language_selection = driver.find_element(
        By.XPATH, ".//*[@class = 'language-selection' ]")
    driver.switch_to.active_element.send_keys(Keys.ESCAPE)

except:
    pass '''

# driver.save_screenshot("screenshot.png")
# Image('screenshot.png')

# elements.screenshot("screenshot.png")
# Image('screenshot.png')
# Out:
# C:\Users\bobby\AppData\Local\Temp\ipykernel_19060\3560011284.py:1: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome('chromedriver', chrome_options=chrome_options)
# ' try:\n    language_selection = driver.find_element(\n        By.XPATH, ".//*[@class = \'language-selection\' ]")\n    driver.switch_to.active_element.send_keys(Keys.ESCAPE)\n\nexcept:\n    pass '

# %%
product_list = []

reading = True
item = 1
item_all = 0
page = 1  # Shopee page = 0

shop_name = 'edifier-direct' #'apple' 'sony-official-store'

try:
    while reading == True:

        url = 'https://www.lazada.co.th/' + shop_name + '/?from=wangpu&pageTypeId=2&q=All-Products&style=wf&page=' + \
            str(page) + '&sort=popularity'
        #url = 'https://shopee.co.th/ctykshp.th?page=' + str(page) + "&sortBy=ctime"

        driver.get(url)
        time.sleep(10)
        # time.sleep(5)

        all_product = driver.find_element(
            By.XPATH, ".//*[@data-qa-locator = 'general-products' ]")
        try:
            product_item = all_product.find_elements(
                By.XPATH, ".//*[@data-qa-locator = 'product-item' ]")
        except:
            product_item = []

        item_all += len(product_item)

        print("Page :", page)
        print("Products of Page :", len(product_item))
        print("Total of Products :", item_all)

        if len(product_item) > 0:
            for i in range(len(product_item)):
                data = {}

                data["Product_ID"] = item

                product_url = product_item[i].find_element(
                    By.TAG_NAME, "a").get_attribute('href')

                #end = product_url.find("?sp_atk=")
                #product_url = product_url[0:end]

                data["Link"] = product_url
                data["Name"] = ""
                data["Status"] = "Sale"
                data["Scan Status"] = "Non-Complete"

                # print(item)
                item += 1
                product_list.append(data)
        else:
            break

        page += 1
except:
    print("Scan is done.")
    pass
# Out:
# Page : 1
# Products of Page : 27
# Total of Products : 27
# Scan is done.

# %%
len(product_list)
# Out:
# 27

# %%
df_product_list = pd.DataFrame(product_list)
df_product_list
# Out:
#     Product_ID                                               Link Name Status  \
# 0            1  https://www.lazada.co.th/products/edifier-dire...        Sale
# 1            2  https://www.lazada.co.th/products/edifier-tws2...        Sale
# 2            3  https://www.lazada.co.th/products/edifier-w820...        Sale
# 3            4  https://www.lazada.co.th/products/edifier-w220...        Sale
# 4            5  https://www.lazada.co.th/products/edifier-earp...        Sale
# 5            6  https://www.lazada.co.th/products/edifier-mp10...        Sale
# 6            7  https://www.lazada.co.th/products/edifier-mf20...        Sale
# 7            8  https://www.lazada.co.th/products/edifier-p180...        Sale
# 8            9  https://www.lazada.co.th/products/edifier-dire...        Sale
# 9           10  https://www.lazada.co.th/products/edifier-p205...        Sale
# 10          11  https://www.lazada.co.th/products/edifier-to-u...        Sale
# 11          12  https://www.lazada.co.th/products/edifier-dire...        Sale
# 12          13  https://www.lazada.co.th/products/edifier-dire...        Sale
# 13          14  https://www.lazada.co.th/products/edifier-tws1...        Sale
# 14          15  https://www.lazada.co.th/products/edifier-mp23...        Sale
# 15          16  https://www.lazada.co.th/products/edifier-stax...        Sale
# 16          17  https://www.lazada.co.th/products/edifier-dire...        Sale
# 17          18  https://www.lazada.co.th/products/edifier-w800...        Sale
# 18          19  https://www.lazada.co.th/products/edifier-heca...        Sale
# 19          20  https://www.lazada.co.th/products/edifier-neob...        Sale
# 20          21  https://www.lazada.co.th/products/edifier-w240...        Sale
# 21          22  https://www.lazada.co.th/products/edifier-dire...        Sale
# 22          23  https://www.lazada.co.th/products/edifier-to-u...        Sale
# 23          24  https://www.lazada.co.th/products/edifier-to-u...        Sale
# 24          25  https://www.lazada.co.th/products/edifier-wh50...        Sale
# 25          26  https://www.lazada.co.th/products/edifier-dire...        Sale
# 26          27  https://www.lazada.co.th/products/edifier-cc20...        Sale
#
#      Scan Status
# 0   Non-Complete
# 1   Non-Complete
# 2   Non-Complete
# 3   Non-Complete
# 4   Non-Complete
# 5   Non-Complete
# 6   Non-Complete
# 7   Non-Complete
# 8   Non-Complete
# 9   Non-Complete
# 10  Non-Complete
# 11  Non-Complete
# 12  Non-Complete
# 13  Non-Complete
# 14  Non-Complete
# 15  Non-Complete
# 16  Non-Complete
# 17  Non-Complete
# 18  Non-Complete
# 19  Non-Complete
# 20  Non-Complete
# 21  Non-Complete
# 22  Non-Complete
# 23  Non-Complete
# 24  Non-Complete
# 25  Non-Complete
# 26  Non-Complete

# %%
from logging import ERROR
driver = webdriver.Chrome('chromedriver', chrome_options=chrome_options)

def scan_comment(product_review):
    
    for j in range(len(product_review)):
        data = {}
        try:
            data["Review_Name"] = product_review[j].find_element(
                By.XPATH, ".//*[@class = 'middle' ]").text
        except:
            print("ERROR : Review_Name")
            pass

        try:
            Rating_Time = product_review[j].find_element(
                By.XPATH, ".//*[@class = 'title right' ]").text
            data["Rating_Time"] = Rating_Time
        except:
            print("ERROR : Rating_Time")
            pass

        try:
            Comment = product_review[j].find_element(
                By.XPATH, ".//*[@class = 'content' ]").text
            data["Comment"] = Comment
        except:
            #print("ERROR : Comment")
            pass

        #data["Review_text"] = product_review[k].text
        review_list.append(data)

def driver_maximize_window():
    driver.maximize_window()

    # obtain browser height and width
    w = driver.execute_script('return document.body.parentNode.scrollWidth')
    h = driver.execute_script('return document.body.parentNode.scrollHeight')
    # set to new window size
    driver.set_window_size(w, h)
# Out:
# C:\Users\bobby\AppData\Local\Temp\ipykernel_19060\4226568.py:2: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome('chromedriver', chrome_options=chrome_options)

# %%
count_error = 0

while len(df_product_list.loc[df_product_list['Scan Status'] == 'Non-Complete']) != 0:

    print('Non-Complete :',
          len(df_product_list.loc[df_product_list['Scan Status'] == 'Non-Complete']))

    driver = webdriver.Chrome('chromedriver', chrome_options=chrome_options)

    count = 0

    # for i in range(4):
    for i in range(len(product_list)):

        driver_maximize_window()

        result = None

        if product_list[i]["Scan Status"] != "Complete":
            try:
                while result is None:

                    url = product_list[i]["Link"]
                    driver.get(url)
                    # time.sleep(5)
                    time.sleep(10)

                    product_title = driver.find_element(
                        By.XPATH, ".//*[@class = 'pdp-mod-product-badge-wrapper' ]")
                    product_name = product_title.find_element(
                        By.TAG_NAME, "h1").text
                    result = product_name
                    print(i+1, product_name)
                    product_list[i]["Name"] = product_name

                    if product_list[i]["Name"] != "":
                        try:
                            product_price = driver.find_element(
                                By.XPATH, ".//*[@class = 'pdp-product-price' ]")
                            product_sell_price = product_price.find_element(
                                By.XPATH, ".//*[@class = 'pdp-price pdp-price_type_normal pdp-price_color_orange pdp-price_size_xl' ]").text
                            product_list[i]["Sell Price"] = product_sell_price
                        except:
                            print("ERROR : Non-Detect Sell Price")
                            pass

                        try:
                            product_original_price = product_price.find_element(
                                By.XPATH, ".//*[@class = 'pdp-price pdp-price_type_deleted pdp-price_color_lightgray pdp-price_size_xs' ]").text
                            product_list[i]["Original Price"] = product_original_price
                        except:
                            product_list[i]["Original Price"] = product_list[i]["Sell Price"]
                            print("ERROR : Non-Detect Original Price")
                            pass

                        try:
                            score_average = driver.find_element(
                                By.XPATH, ".//*[@class = 'score-average' ]").text
                            product_list[i]["Score Average"] = score_average
                        except:
                            # product_list[i]["Score Average"] = 'Non-Detect'
                            print("ERROR : Non-Detect Score Average")
                            pass

                        try:
                            text_num_product_sell = driver.find_element(
                                By.XPATH, ".//*[@class = 'quantity-content-default' ]").text
                            num_product_sell = re.sub(
                                r'[^0-9]', '', text_num_product_sell)
                            product_list[i]["Num of Sell"] = int(
                                num_product_sell)
                        except:
                            print("ERROR : Non-Detect Num of Sell")
                            pass

                        try:
                            product_review_list = driver.find_element(
                                By.XPATH, ".//*[@class = 'mod-reviews' ]")

                            try:
                                count_review = 0

                                review_list = []

                                element = driver.find_element(
                                    By.XPATH, ".//*[@class = 'next-pagination-pages' ]")
                                element_button = element.find_elements(
                                    By.TAG_NAME, "button")

                                product_review_list = driver.find_element(
                                    By.XPATH, ".//*[@class = 'mod-reviews' ]")
                                product_review = product_review_list.find_elements(
                                    By.XPATH, ".//*[@class = 'item' ]")
                                count_review += len(product_review)

                                scan_comment(product_review)

                                while element_button[-1].get_attribute('disabled') != 'true':

                                    driver.execute_script(
                                        "arguments[0].click();", element_button[-1])
                                    time.sleep(5)

                                    element = driver.find_element(
                                        By.XPATH, ".//*[@class = 'next-pagination-pages' ]")
                                    element_button = element.find_elements(
                                        By.TAG_NAME, "button")

                                    product_review_list = driver.find_element(
                                        By.XPATH, ".//*[@class = 'mod-reviews' ]")
                                    product_review = product_review_list.find_elements(
                                        By.XPATH, ".//*[@class = 'item' ]")

                                    scan_comment(product_review)

                                    count_review += len(product_review)

                                    # จำกัด 20 Reviews
                                    if count_review >= 20:
                                        break

                                product_list[i]["Num of Reviews"] = len(
                                    review_list)
                                print("Num of Reviews :", len(review_list))
                                product_list[i]["Review"] = review_list

                            except:
                                product_list[i]["Num of Reviews"] = len(
                                    review_list)
                                print("Num of Reviews :", len(review_list))
                                product_list[i]["Review"] = review_list
                                print("ERROR : Review")
                                pass

                        except:
                            print("Non-Detect Review")
                            #product_list[i]["Num of Review"] = 0
                            pass

                    # product_list[i]["Scan Status"] = "Complete"

                    ''' if product_list[i]["Name"] != "":

                        try:
                            product_sell_price = driver.find_element(
                                By.XPATH, ".//*[@class = '_2Shl1j' ]").text
                            product_list[i]["Sell Price"] = product_sell_price
                        except:
                            print("ERROR : Non-Detect Sell Price")
                            pass

                        try:
                            product_original_price = driver.find_element(
                                By.XPATH, ".//*[@class = '_2yjfFH' ]").text
                            product_list[i]["Original Price"] = product_original_price
                        except:
                            product_list[i]["Original Price"] = product_list[i]["Sell Price"]
                            print("ERROR : Non-Detect Original Price")
                            pass

                        try:
                            text_favorite = driver.find_element(
                                By.XPATH, ".//*[@class = 'flex items-center _3CF_vE' ]").text
                            #num_favorite = re.sub(r'[^0-9]', '', text_favorite)
                            #product_list[i]["Favorite"] = int(num_favorite)
                            product_list[i]["Favorite"] = text_favorite
                        except:
                            print("ERROR : Non-Detect Num-Favorite")
                            pass

                        try:
                            text_selled = driver.find_element(
                                By.XPATH, ".//*[@class = 'HmRxgn' ]").text
                            #product_list[i]["Selled"] = int(num_selled)
                            product_list[i]["Selled"] = text_selled
                        except:
                            print("ERROR : Non-Detect Num-Selled")
                            pass

                        try:
                            text_num_product = driver.find_element(
                                By.XPATH, ".//*[@class = 'flex items-center _283ldj' ]")
                            text_num_product_sell = text_num_product.find_element(
                                By.XPATH, ".//*[@class = 'flex items-center' ]").text
                            num_product_sell = re.sub(
                                r'[^0-9]', '', text_num_product_sell)
                            product_list[i]["Num of Sell"] = int(
                                num_product_sell)
                        except:
                            pass

                        try:
                            product_review_list = driver.find_element(
                                By.XPATH, ".//*[@class = 'shopee-product-comment-list' ]")

                            try:
                                count_review = 0
                                review_list = []

                                element = driver.find_element(
                                    By.XPATH, ".//*[@class = 'shopee-page-controller product-ratings__page-controller' ]")
                                test = element.find_element(
                                    By.CSS_SELECTOR, ".shopee-icon-button--right")
                                button = element.find_elements(
                                    By.TAG_NAME, "button")

                                product_review_list = driver.find_element(
                                    By.XPATH, ".//*[@class = 'shopee-product-comment-list' ]")
                                product_review = product_review_list.find_elements(
                                    By.XPATH, ".//*[@class = 'shopee-product-rating__main' ]")
                                count_review += len(product_review)

                                scan_comment(product_review)

                                while button[-2].get_attribute("class") != 'shopee-button-solid shopee-button-solid--primary':

                                    driver.execute_script(
                                        "arguments[0].click();", test)
                                    time.sleep(5)

                                    element = driver.find_element(
                                        By.XPATH, ".//*[@class = 'shopee-page-controller product-ratings__page-controller' ]")
                                    test = element.find_element(
                                        By.CSS_SELECTOR, ".shopee-icon-button--right")
                                    button = element.find_elements(
                                        By.TAG_NAME, "button")

                                    product_review_list = driver.find_element(
                                        By.XPATH, ".//*[@class = 'shopee-product-comment-list' ]")
                                    product_review = product_review_list.find_elements(
                                        By.XPATH, ".//*[@class = 'shopee-product-rating__main' ]")

                                    scan_comment(product_review)

                                    # จำกัด 100 Reviews
                                    count_review += len(product_review)
                                    if count_review >= 100:
                                        break

                                #product_list[i]["Num of Review"] = count_review
                                product_list[i]["Num of Reviews"] = len(
                                    review_list)
                                print("Num of Reviews :", len(review_list))
                                product_list[i]["Review"] = review_list

                                #print("A", len(product_review))
                                #print("B", count_review)

                            except:
                                print("ERROR : Review")
                                pass

                        except:
                            print("Non-Detect Review")
                            #product_list[i]["Num of Review"] = 0
                            pass '''

            except:
                print(i+1, "ERROR")
                product_list[i]["Scan Status"] = "Non-Complete"
                driver.quit()

                driver = webdriver.Chrome(
                    'chromedriver', chrome_options=chrome_options)
                driver_maximize_window()
                pass

    count_error += 1
    df_product_list = pd.DataFrame(product_list)

    if count_error >= 3:
        break
# Out:
# Non-Complete : 27
# C:\Users\bobby\AppData\Local\Temp\ipykernel_19060\1647608047.py:8: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome('chromedriver', chrome_options=chrome_options)
# 1 Edifier Direct หูฟังบลูทูธ หูฟังไร้สาย Edifier X5 Wireless Earbuds Bluetooth 5.0 ลดเสียงรบกวนจากการโทร IP55 กันฝุ่นและกันน้ำ
# ERROR : Non-Detect Score Average
# ERROR : Non-Detect Num of Sell
# Non-Detect Review
# 2 Edifier TWS200 Plus True Wireless Stereo Earbuds หูฟังไร้สาย Qualcomm AptX Bluetooth 5.2 up to 24hrs playtime Noise Cancellation
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 3 Edifier W820 NB หูฟังคาดหัว หูฟังไร้สาย ตัดเสียงรบกวน Hi-Res Audio Hybird ANC Type-C Fast Charging Bluetooth V5.0
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 4 Edifier รุ่นใหม่ W220T TWS หูฟังไร้สายบลูทูธ 5.3 ใช้งานได้ถึง 24 ชั่วโมง ตัดเสียงรบกวนดีเยี่ยม กันน้ำได้ ชาร์จเร็ว QCC3056 IP54 รับประกัน 1 ปี
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 5 Edifier Earphone Bag Compatible for Earphone Earbuds with Edifier Logo（New）
# ERROR : Non-Detect Original Price
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 6 Edifier MP100 PLUS ลำโพงบลูทูธไร้สายแบบพกพา กันน้ำระดับ IPX7 ลำโพงไร้สายพร้อมด้วยไมโครโฟนตัดเสียงรบกวน ใช้งานได้นานถึง 9 ชั่วโมง สำหรับใช้งานในบ้าน นอกบ้าน และขณะเดินทาง
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 10
# 7 Edifier MF200 Portable Tabletop Bluetooth Speaker 10 hours of playtime Bluetooth 5.0 AUX USBC Connection Touch Control
# ERROR : Non-Detect Num of Sell
# Non-Detect Review
# 8 Edifier P180 Plus/USBC in-ear Earphone Ear buds with Remote and Mic
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 9 Edifier Direct หูฟังบลูทูธ หูฟังไร้สาย TWS330 NB Wireless Bluetooth Noise Cancelling Earbuds ตัดเสียงรบกวน Bluetooth 5.0 Hybrid ANC
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 10 Edifier P205 in-ear Earphone Build-in Mic Bass พร้อมไมโครโฟนและระบบควบคุมแบบอินไลน์
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 11 EDIFIER TO-U6+ True Wireless In-Ear หูฟังไร้สาย Headphones Bluetooth Earbuds Bluetooth 5.0 Wireless Charge CVC Call Noise Cancellation Dust and Waterproof Ergonomically Design Fashion Color
# ERROR : Non-Detect Num of Sell
# ERROR : Review
# 12 Edifier Direct หูฟังบลูทูธ หูฟังไร้สาย X2 TWS Earbuds Bluetooth earphone 5.1 up to 28hrs playtime Game Mode Sports กันน้ำ IPX54 เบสหนัก
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 13 Edifier Direct Neobuds Pro TWS หูฟังบลูทูธ หูฟังไร้สาย หูฟังอินเอียร์ ตัดเสียงรบกวน พร้อมกล่องชาร์จ สามารถใช้กับไอโฟน แอนดรอยด์
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 14 Edifier TWS1 Pro True Wireless Bluetooth Earbuds หูฟังไร้สาย หูฟังบลูทูธ V5.2 การตัดเสียงรบกวน CVC8.0 IP65 กันฝุ่นกันน้ำ
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 15 Edifier MP230 ลำโพงบลูทูธพกพา ใช้งานได้นานถึง 10 ชั่วโมงต่อการชาร์จหนึ่งครั้ง มีการออกแบบที่เป็นคลาสสิกและมีฟูลเรนจ์ไดร์เวอร์บลูทูธ 5.0 ไมโคร SD
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 16 EDIFIER STAX SPIRIT S3 หูฟังแบบครอบหูตัดเสียงรบกวน Wireless Over Ear Headphone Hi-Res รองรับ Qualcomm® aptX™Adaptive Type-C เชื่อมต่อด้วย Bluetooth V5.2 with FULL-SIZE ไดร์เวอร์ PLANA
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 8
# 17 Edifier Direct X3 Wireless Earbuds หูฟังไร้สาย หูฟังบลูทูธ Bluetooth 5.0 การตัดเสียงรบกวน cVc8.0 IPX5 กันฝุ่นและกันน้ำ
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 18 Edifier หูฟังคาดหัว หูฟังครอบหู หูฟังบลูทูธ W800BT Plus หูฟังครอบหู Bluetooth On-Ear Headset Qualcomm aptX 40mm Driver ใช้งานได้ 55 ชั่วโมง
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 19 EDIFIER HECATE GX07 สุดยอดหูฟังเกมมิ่งไร้สาย ดีเลย์น้อย มิติเสียงระดับเทพ, การตัดเสียงรบกวนแบบไฮบริด LHDC ANC Dual Ambient Noise Cancelling Microphone
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 15
# 20 EDIFIER Neobuds S หูฟัง ไร้สาย Wireless Bluetooth Earbuds หูฝังบลูทูธ ตัดเสียงรบกวน Qualcomm Snapdragon Sound Game mode with Hybrid Active Noise Cancelling สามารถใช้กับไอโฟน แอนดรอยด์
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 15
# 21 Edifier W240TN TWS หูฟังไร้สายบลูทูธหูฟังไร้สาย AI ตัดเสียงรบกวนบลูทูธ 5.3 กันน้ำพร้อมไมโครโฟนโหมดเกมชาร์จเร็วสำหรับ Android และ IOS
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 22 Edifier Direct W280NB ชุดหูฟังบลูทูธ หูฟังไร้สาย สำหรับเล่นกีฬา หูฟังตัดเสียงรบกวน Wireless Sports Headphones with Active Noise Cancellation
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 23 Edifier TO-U7 Pro True Wireless Noise Cancellation Earbuds 18 hours หูฟังไร้สาย หูฟังบลูทูธ Bluetooth 5.3 Bluetooth Earbuds Waterproof Game Mode
# ERROR : Non-Detect Num of Sell
# Non-Detect Review
# 24 Edifier TO-U2 mini True Wireless Earbuds หูฟังไร้สาย หูฟังบลูทูธ Bluetooth 5.1 up to 25 hours LED Display IP54 กันฝุ่นกันน้ำ
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 25 Edifier WH500 หูฟังคาดหัว หูฟังไร้สาย ตัดเสียงรบกวน Type-C Fast Charging Bluetooth V5.2
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 26 Edifier Direct TWS NB2 Pro Wireless Bluetooth Noise Cancelling Earbuds หูฟังบลูทูธ หูฟังไร้สาย ตัดเสียงรบกวน กันฝุ่นและกันน้ำ IP65
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20
# 27 Edifier CC200 Headset Wireless หูฟังบลูทูธ พร้อมไมโครโฟนตัดเสียงรบกวน ที่คาดผมแบบปรับได้สำหรับ ออฟฟิศ เรียนออนไลน์ up to 64 Hours Dual MIC Bluetooth V5.0
# ERROR : Non-Detect Num of Sell
# Num of Reviews : 20

# %%
df_product_list = pd.DataFrame(product_list)
df_product_list
# Out:
#     Product_ID                                               Link  \
# 0            1  https://www.lazada.co.th/products/edifier-dire...
# 1            2  https://www.lazada.co.th/products/edifier-tws2...
# 2            3  https://www.lazada.co.th/products/edifier-w820...
# 3            4  https://www.lazada.co.th/products/edifier-w220...
# 4            5  https://www.lazada.co.th/products/edifier-earp...
# 5            6  https://www.lazada.co.th/products/edifier-mp10...
# 6            7  https://www.lazada.co.th/products/edifier-mf20...
# 7            8  https://www.lazada.co.th/products/edifier-p180...
# 8            9  https://www.lazada.co.th/products/edifier-dire...
# 9           10  https://www.lazada.co.th/products/edifier-p205...
# 10          11  https://www.lazada.co.th/products/edifier-to-u...
# 11          12  https://www.lazada.co.th/products/edifier-dire...
# 12          13  https://www.lazada.co.th/products/edifier-dire...
# 13          14  https://www.lazada.co.th/products/edifier-tws1...
# 14          15  https://www.lazada.co.th/products/edifier-mp23...
# 15          16  https://www.lazada.co.th/products/edifier-stax...
# 16          17  https://www.lazada.co.th/products/edifier-dire...
# 17          18  https://www.lazada.co.th/products/edifier-w800...
# 18          19  https://www.lazada.co.th/products/edifier-heca...
# 19          20  https://www.lazada.co.th/products/edifier-neob...
# 20          21  https://www.lazada.co.th/products/edifier-w240...
# 21          22  https://www.lazada.co.th/products/edifier-dire...
# 22          23  https://www.lazada.co.th/products/edifier-to-u...
# 23          24  https://www.lazada.co.th/products/edifier-to-u...
# 24          25  https://www.lazada.co.th/products/edifier-wh50...
# 25          26  https://www.lazada.co.th/products/edifier-dire...
# 26          27  https://www.lazada.co.th/products/edifier-cc20...
#
#                                                  Name Status   Scan Status  \
# 0   Edifier Direct หูฟังบลูทูธ หูฟังไร้สาย Edifier...   Sale  Non-Complete
# 1   Edifier TWS200 Plus True Wireless Stereo Earbu...   Sale  Non-Complete
# 2   Edifier W820 NB หูฟังคาดหัว หูฟังไร้สาย ตัดเสี...   Sale  Non-Complete
# 3   Edifier รุ่นใหม่ W220T TWS หูฟังไร้สายบลูทูธ 5...   Sale  Non-Complete
# 4   Edifier Earphone Bag Compatible for Earphone E...   Sale  Non-Complete
# 5   Edifier MP100 PLUS ลำโพงบลูทูธไร้สายแบบพกพา กั...   Sale  Non-Complete
# 6   Edifier MF200 Portable Tabletop Bluetooth Spea...   Sale  Non-Complete
# 7   Edifier P180 Plus/USBC in-ear Earphone Ear bud...   Sale  Non-Complete
# 8   Edifier Direct หูฟังบลูทูธ หูฟังไร้สาย TWS330 ...   Sale  Non-Complete
# 9   Edifier P205 in-ear Earphone Build-in Mic Bass...   Sale  Non-Complete
# 10  EDIFIER TO-U6+ True Wireless In-Ear หูฟังไร้สา...   Sale  Non-Complete
# 11  Edifier Direct หูฟังบลูทูธ หูฟังไร้สาย X2 TWS ...   Sale  Non-Complete
# 12  Edifier Direct Neobuds Pro TWS หูฟังบลูทูธ หูฟ...   Sale  Non-Complete
# 13  Edifier TWS1 Pro True Wireless Bluetooth Earbu...   Sale  Non-Complete
# 14  Edifier MP230 ลำโพงบลูทูธพกพา ใช้งานได้นานถึง ...   Sale  Non-Complete
# 15  EDIFIER STAX SPIRIT S3 หูฟังแบบครอบหูตัดเสียงร...   Sale  Non-Complete
# 16  Edifier Direct X3 Wireless Earbuds หูฟังไร้สาย...   Sale  Non-Complete
# 17  Edifier หูฟังคาดหัว หูฟังครอบหู หูฟังบลูทูธ W8...   Sale  Non-Complete
# 18  EDIFIER HECATE GX07 สุดยอดหูฟังเกมมิ่งไร้สาย ด...   Sale  Non-Complete
# 19  EDIFIER Neobuds S หูฟัง ไร้สาย Wireless Blueto...   Sale  Non-Complete
# 20  Edifier W240TN TWS หูฟังไร้สายบลูทูธหูฟังไร้สา...   Sale  Non-Complete
# 21  Edifier Direct W280NB ชุดหูฟังบลูทูธ หูฟังไร้ส...   Sale  Non-Complete
# 22  Edifier TO-U7 Pro True Wireless Noise Cancella...   Sale  Non-Complete
# 23  Edifier TO-U2 mini True Wireless Earbuds หูฟัง...   Sale  Non-Complete
# 24  Edifier WH500 หูฟังคาดหัว หูฟังไร้สาย ตัดเสียง...   Sale  Non-Complete
# 25  Edifier Direct TWS NB2 Pro Wireless Bluetooth ...   Sale  Non-Complete
# 26  Edifier CC200 Headset Wireless หูฟังบลูทูธ พร้...   Sale  Non-Complete
#
#     Sell Price Original Price Score Average  Num of Reviews  \
# 0      ฿869.00      ฿1,699.00           NaN             NaN
# 1    ฿1,449.00      ฿1,999.00           4.8            20.0
# 2    ฿1,729.00      ฿2,990.00           4.9            20.0
# 3    ฿1,699.00      ฿2,699.00           4.9            20.0
# 4      ฿120.00        ฿120.00           5.0            20.0
# 5    ฿1,998.00      ฿3,299.00           4.9            10.0
# 6    ฿3,099.00      ฿3,999.00             0             NaN
# 7      ฿379.00        ฿599.00           4.9            20.0
# 8    ฿1,190.00      ฿2,999.00           4.8            20.0
# 9      ฿299.00        ฿399.00           4.9            20.0
# 10   ฿1,999.00      ฿3,299.00           4.5             NaN
# 11     ฿669.00        ฿999.00           4.9            20.0
# 12   ฿3,980.00      ฿5,999.00           4.9            20.0
# 13   ฿1,279.00      ฿2,199.00           4.9            20.0
# 14   ฿4,190.00      ฿5,999.00           5.0            20.0
# 15  ฿12,599.00     ฿14,699.00           5.0             8.0
# 16     ฿799.00      ฿1,499.00           4.9            20.0
# 17   ฿1,179.00      ฿1,890.00           4.9            20.0
# 18   ฿3,389.00      ฿6,299.00           4.9            15.0
# 19   ฿5,509.00      ฿6,990.00           4.9            15.0
# 20   ฿2,699.00      ฿3,590.00           5.0            20.0
# 21   ฿1,569.00      ฿2,399.00           4.9            20.0
# 22   ฿3,899.00      ฿4,890.00             0             NaN
# 23   ฿1,679.00      ฿2,399.00           4.9            20.0
# 24   ฿1,719.00      ฿2,899.00           4.9            20.0
# 25   ฿2,319.00      ฿3,999.00           4.9            20.0
# 26   ฿1,739.00      ฿2,290.00           4.7            20.0
#
#                                                Review
# 0                                                 NaN
# 1   [{'Review_Name': 'โดย PomPam😽🐾ตรวจสอบว่ามีการส...
# 2   [{'Review_Name': 'โดย Parthตรวจสอบว่ามีการสั่ง...
# 3   [{'Review_Name': 'โดย g***kตรวจสอบว่ามีการสั่ง...
# 4   [{'Review_Name': 'โดย P***.ตรวจสอบว่ามีการสั่ง...
# 5   [{'Review_Name': 'โดย กิตตรวจสอบว่ามีการสั่งซื...
# 6                                                 NaN
# 7   [{'Review_Name': 'โดย ช***.ตรวจสอบว่ามีการสั่ง...
# 8   [{'Review_Name': 'โดย Anookul M.ตรวจสอบว่ามีกา...
# 9   [{'Review_Name': 'โดย ส***8ตรวจสอบว่ามีการสั่ง...
# 10                                                NaN
# 11  [{'Review_Name': 'โดย 0***5ตรวจสอบว่ามีการสั่ง...
# 12  [{'Review_Name': 'โดย Piphat C.ตรวจสอบว่ามีการ...
# 13  [{'Review_Name': 'โดย Raf S.ตรวจสอบว่ามีการสั่...
# 14  [{'Review_Name': 'โดย A***.ตรวจสอบว่ามีการสั่ง...
# 15  [{'Review_Name': 'โดย พ***.ตรวจสอบว่ามีการสั่ง...
# 16  [{'Review_Name': 'โดย วิวัฒนา อ.ตรวจสอบว่ามีกา...
# 17  [{'Review_Name': 'โดย 0***2ตรวจสอบว่ามีการสั่ง...
# 18  [{'Review_Name': 'โดย 0***4ตรวจสอบว่ามีการสั่ง...
# 19  [{'Review_Name': 'โดย อ***.ตรวจสอบว่ามีการสั่ง...
# 20  [{'Review_Name': 'โดย Thapanee B.ตรวจสอบว่ามีก...
# 21  [{'Review_Name': 'โดย J***.ตรวจสอบว่ามีการสั่ง...
# 22                                                NaN
# 23  [{'Review_Name': 'โดย 6***5ตรวจสอบว่ามีการสั่ง...
# 24  [{'Review_Name': 'โดย torsak W.ตรวจสอบว่ามีการ...
# 25  [{'Review_Name': 'โดย จ***.ตรวจสอบว่ามีการสั่ง...
# 26  [{'Review_Name': 'โดย kitisakตรวจสอบว่ามีการสั...

# %%
product_list
# Out:
# [{'Product_ID': 1,
#   'Link': 'https://www.lazada.co.th/products/edifier-direct-edifier-x5-wireless-earbuds-bluetooth-50-ip55-i2544667414.html',
#   'Name': 'Edifier Direct หูฟังบลูทูธ หูฟังไร้สาย Edifier X5 Wireless Earbuds Bluetooth 5.0 ลดเสียงรบกวนจากการโทร IP55 กันฝุ่นและกันน้ำ',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿869.00',
#   'Original Price': '฿1,699.00'},
#  {'Product_ID': 2,
#   'Link': 'https://www.lazada.co.th/products/edifier-tws200-plus-true-wireless-stereo-earbuds-qualcomm-aptx-bluetooth-52-up-to-24hrs-playtimenoise-cancellation-i3284890319.html',
#   'Name': 'Edifier TWS200 Plus True Wireless Stereo Earbuds หูฟังไร้สาย Qualcomm AptX Bluetooth 5.2 up to 24hrs playtime Noise Cancellation',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿1,449.00',
#   'Original Price': '฿1,999.00',
#   'Score Average': '4.8',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย PomPam😽🐾ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '14 พ.ค. 2022',
#     'Comment': 'ได้รับสินค้าเรียบร้อยค่ะ ส่งจากจีนแต่ได้ไวมากๆ แพคมาอย่างดีสินค้าไม่เสียหาย สินค้าตรงปก ของดีเสียงฟังชัดแจ๋ว ชอบมากๆ ค่ะ แนะนําร้านนี้ ราคาดีคุ้มค่ามาก'},
#    {'Review_Name': 'โดย ชญานิษฎ์ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '14 พ.ค. 2022',
#     'Comment': 'แพคกิ้งดีมากกกกกกั้นกระแทกหลายชั้นเลยชอบมากค่ะ\nลองฟังแล้วเสียงเพราะมากสั่งครั้งแรกถูกใจสุดๆเลยค่ะ\nพกพาง่ายชาร์ตแบตแปปเดียวเต็มสีดำสวยสุดๆเลย\nโดยรวมถูกใจมากค่ะ'},
#    {'Review_Name': 'โดย 8***5ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '09 พ.ค. 2022',
#     'Comment': 'ส่งของมาเร็ว แพ็คมาดี ใช้งานง่าย'},
#    {'Review_Name': 'โดย 8***8ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '09 พ.ค. 2022',
#     'Comment': 'แนะนำเลยค่ะ พกพาสะดวก น่ารัก คุณภาพเยี่ยม ❤️❤️❤️'},
#    {'Review_Name': 'โดย ศศิญา ไ.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '09 พ.ค. 2022',
#     'Comment': 'กล่องแพ็คมาอย่างดี มีกันกระแทก แพ็คเก็จดีงาม ถูกใจสุดๆๆๆๆๆๆๆๆๆๆๆๆๆๆๆ'}]},
#  {'Product_ID': 3,
#   'Link': 'https://www.lazada.co.th/products/edifier-w820-nb-hi-res-audio-hybird-anc-type-c-fast-charging-bluetooth-v50-i2566757204.html',
#   'Name': 'Edifier W820 NB หูฟังคาดหัว หูฟังไร้สาย ตัดเสียงรบกวน Hi-Res Audio Hybird ANC Type-C Fast Charging Bluetooth V5.0',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿1,729.00',
#   'Original Price': '฿2,990.00',
#   'Score Average': '4.9',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย Parthตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '16 ม.ค. 2022',
#     'Comment': 'Suoerb product, very good battery life. Buy it if you can afford.'},
#    {'Review_Name': 'โดย เทอดศักดิ์ ส.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '16 ธ.ค. 2021',
#     'Comment': 'ประทับใจมากส่งใส่กล่องมาดีมาก มีกันกระแทกอย่างดี ทดลองใช้ เสียงดีมาก กลาง แหลม ทุ้ม มาชัดดี ดีกว่าที่เคยซื้อ 2อันที่ราคาไม่เกิน 800฿ อย่างชัดเจนมาก ANC ใช้ได้ในระดับหนึ่ง ก็สมกับราคาที่ได้มานี้ (1369฿)'},
#    {'Review_Name': 'โดย ธัชชัย ศ.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '03 เม.ย. 2022',
#     'Comment': 'หีบห่อดี มีกันกระแทก ส่งเร็วมาก ห้าวันถึง หูนิ่มมาก ก่อนหน้าประทับใจ ANC ของ Neobuds Pro เลยซื้อแบบครอบหูเพิ่มเติม ANC โอเคแต่รู้สึก Neobuds pro ดีกว่า ลองฟังเสียงชอบที่เบสไม่เยอะไป(Neobuds Pro เบสเยอะไป) สวมใส่บีบหัวน้อยกว่าหูฟังที่เคยมี ใส่นานห้องพัดลมมีเหงื่อออก'},
#    {'Review_Name': 'โดย takonkij V.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '2 วันก่อน',
#     'Comment': 'this is my 2nd pair the sound quality is superb compared to the price you pay. my wife love the first pair so bad and i tried hers and have to grab myself a pair too'},
#    {'Review_Name': 'โดย ฑ***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '5 วันก่อน',
#     'Comment': 'ได้รับสินค้าหลังสั่งซื้อประมาณ 1 สัปดาห์ แพคสินค้ามาไม่ดี กล่องบุบ แต่ยังดีหูฟังไม่เสียหาย'}]},
#  {'Product_ID': 4,
#   'Link': 'https://www.lazada.co.th/products/edifier-w220t-tws-53-24-qcc3056-ip54-1-i3640204764.html',
#   'Name': 'Edifier รุ่นใหม่ W220T TWS หูฟังไร้สายบลูทูธ 5.3 ใช้งานได้ถึง 24 ชั่วโมง ตัดเสียงรบกวนดีเยี่ยม กันน้ำได้ ชาร์จเร็ว QCC3056 IP54 รับประกัน 1 ปี',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿1,699.00',
#   'Original Price': '฿2,699.00',
#   'Score Average': '4.9',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย g***kตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '07 ก.ย. 2022',
#     'Comment': 'เสียงค่อนข้างดีเลยค่ะ ลองใช้แล้วววว น่ารักมากเลยค่ ไม่เจ็บหูด้วย 🤍🤍🤍🤍🤍🤍🤍🤍🤍💗💗💗💗💗💗💗💗💗💗💗💗💗💗💗💗💗💗💗💗💗💗💗💗💗💗💗💗'},
#    {'Review_Name': 'โดย 8***5ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '05 ก.ย. 2022',
#     'Comment': 'จัดส่งไวมากๆเลยสั่งไม่กี่วันได้ของแล้วสินค้าแพ็คมาอย่างดีใส่พลาสติกกันกระแทกมาให้ด้วยครับเปิดกล่องได้สินค้าตามที่สั่งโดยรวมถือว่าดีมากครั้งต่อไปจะสั่งร้านนี้อีก'},
#    {'Review_Name': 'โดย เสกสรร ว.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '20 ก.ค. 2022',
#     'Comment': 'จัดส่งสินค้าในระยะเวลาไม่นานมาก\nตอนแรกเห็นว่ามีสินค้าในคลังลาซาด้าเขียนไว้อย่างนั้น\nเอาเข้าจริงต้องนำเข้าจากฮ่องกง\nพอได้รับสินค้าแล้วก็เทสดู เสียงก็ดีจริงๆครับ เป็นเพราะหูฟังตัวนี้มี DAC ในตัว พอเสียบเข้ากับ Samsung เปิด Poweramp ก็ขึ้นว่า USB-DAC เลย ถือว่าพอใจมากกับราคสและคุณภาพเสียงที่รองรับ Hi Res ด้วย'},
#    {'Review_Name': 'โดย Dollar N.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '14 ก.ค. 2022',
#     'Comment': 'ได้เป็นของเเถมจากการซื้อ edifier nb2 pro ส่งเร็ว😁ขนาดจากจีนเเค่ 6 วันได้ เร็วมากก💯✨สภาพสินค้าใหม่ สมบูรณ์ เเต่ยังไม่ได้ลองเทสเสียง👍'},
#    {'Review_Name': 'โดย N***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '29 ส.ค. 2022',
#     'Comment': 'ส่งไว สีสวย กล่องดี ลองฟังแล้วสีดัง ชัด ออกแนวนุ่ม ๆ ตอนสั่งมีของแถมเป็นหูฟังแบบสายกับซองมาให้ เชื่อมต่อบลูทูธได้ไว ถ้าหาไม่เจอต้องกดตุ่มด้านหลังตัวกล่องใส่หูฟัง ใช้ง่าย'}]},
#  {'Product_ID': 5,
#   'Link': 'https://www.lazada.co.th/products/edifier-earphone-bag-compatible-for-earphone-earbuds-with-edifier-logonew-i4141892372.html',
#   'Name': 'Edifier Earphone Bag Compatible for Earphone Earbuds with Edifier Logo（New）',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿120.00',
#   'Original Price': '฿120.00',
#   'Score Average': '5.0',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย P***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '2 สัปดาห์ก่อน',
#     'Comment': 'ได้รับสินค้าเรียบร้อยแล้วค่ะ ได้แถมมาตอนซื้อ edifier w820nb ถุงขนาดเล็กกระทัดรัดค่ะ\U0001faf6🏻'},
#    {'Review_Name': 'โดย lifeisgettingweirderตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '2 สัปดาห์ก่อน',
#     'Comment': 'ได้แถมมากับฝตอนซื้อหูฟังค่ะ ถุงคุณภาพดีมากกก ไม่เหมือนของแถมเลยเนื้อเรียนมือมากก ถุงก็หนา ดูดี ดูมีราคา'},
#    {'Review_Name': 'โดย สารทูล อ.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '3 สัปดาห์ก่อน',
#     'Comment': 'ของแถมหรูหรา หูฟังได้ตอนลดราคาไม่พอยังได้ของแถมตั้ง2ชิ้น คุ้มเกินคุ้ม คุ้มค่าคุณภาพเกินราคา'},
#    {'Review_Name': 'โดย Hyunesuaตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '2 สัปดาห์ก่อน',
#     'Comment': 'เล็กน่ารัก พกพาง่าย สามารถจัดระเบียบให้กระเป๋าได้ ได้แถมมาจาก11.11 คุ้มมากกก เก๋มาก เยี่ยม'},
#    {'Review_Name': 'โดย W***4ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '1 สัปดาห์ก่อน',
#     'Comment': 'ได้เป็นของเเถมจากการซื้อหูฟัง คุ้มค่ามากค่ะ\n\nได้เป็นของเเถมจากการซื้อหูฟัง คุ้มค่ามากค่ะ'}]},
#  {'Product_ID': 6,
#   'Link': 'https://www.lazada.co.th/products/edifier-mp100-plus-ipx7-9-i3980101605.html',
#   'Name': 'Edifier MP100 PLUS ลำโพงบลูทูธไร้สายแบบพกพา กันน้ำระดับ IPX7 ลำโพงไร้สายพร้อมด้วยไมโครโฟนตัดเสียงรบกวน ใช้งานได้นานถึง 9 ชั่วโมง สำหรับใช้งานในบ้าน นอกบ้าน และขณะเดินทาง',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿1,998.00',
#   'Original Price': '฿3,299.00',
#   'Score Average': '4.9',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย กิตตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '3 สัปดาห์ก่อน',
#     'Comment': 'เสียงดี ดังเกินขนาด แถมได้ราคาดีมากๆช่วง 11.11'},
#    {'Review_Name': 'โดย พัฒนพันธุ์ ว.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '12 ก.ย. 2022',
#     'Comment': 'ส่งไวเสียงดีมีของแถมเพียบ'},
#    {'Review_Name': 'โดย ****0ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '18 ก.ย. 2022',
#     'Comment': 'ลำโพงน่ารัก สีสวย กันนำ้ พกพาสดวก'},
#    {'Review_Name': 'โดย ****0ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '18 ก.ย. 2022',
#     'Comment': 'ลำโพงน่ารัก ใช้งานได้ดีมาก ราคาคุ้มค่า'},
#    {'Review_Name': 'โดย พ***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '21 ส.ค. 2022',
#     'Comment': 'น่ารัก เสียงดี ใช้งานง่าย'}]},
#  {'Product_ID': 7,
#   'Link': 'https://www.lazada.co.th/products/edifier-mf200-portable-tabletop-bluetooth-speaker-10-hours-of-playtime-bluetooth-50-aux-usbc-connection-touch-control-i4074258627.html',
#   'Name': 'Edifier MF200 Portable Tabletop Bluetooth Speaker 10 hours of playtime Bluetooth 5.0 AUX USBC Connection Touch Control',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿3,099.00',
#   'Original Price': '฿3,999.00',
#   'Score Average': '0'},
#  {'Product_ID': 8,
#   'Link': 'https://www.lazada.co.th/products/edifier-p180-plususbc-in-ear-earphone-ear-buds-with-remote-and-mic-i3992441381.html',
#   'Name': 'Edifier P180 Plus/USBC in-ear Earphone Ear buds with Remote and Mic',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿379.00',
#   'Original Price': '฿599.00',
#   'Score Average': '4.9',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย ช***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '27 ต.ค. 2022',
#     'Comment': 'สินค้าจัดส่งเร็วมากๆ ค่ะ แพ็คสินค้ามาดี คุณภาพสินค้าดี คุ้มค่ากับราคมค่ะ บริการดีมากๆ'},
#    {'Review_Name': 'โดย pitipong T.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '11 ส.ค. 2022',
#     'Comment': 'เสียงดีใช้ได้ครับ ถึงจะเป็น earbuds แต่ก็เสียงดี'},
#    {'Review_Name': 'โดย 6***5ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '11 ส.ค. 2022',
#     'Comment': 'ได้เป็นของขวัญมาฟรีก็ขอบคุณมากนะคะ แต่ฉันใช้ไม่ได้มันusb อาจจะเพราะรุ่นโทรศัพท์ ของส่งไวมากค่ะ สภาพดีสวยงาม'},
#    {'Review_Name': 'โดย ม***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '05 ก.ย. 2022',
#     'Comment': 'แพ๊คของดี จัดส่งเร็ว มาจากจีนรอไม่นาน คุณภาพเสียงกลางๆใช้งานทั่วไปได้ เสียงกลางแหลมชัด เบสน้อย เหมาะใช้งานทั่วไป..'},
#    {'Review_Name': 'โดย ธ***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '1 วันก่อน',
#     'Comment': 'เสียงสูงอาจจะไม่เด่นมาก แต่ว่าสามารถแยกแต่ละเสียงได้อย่างชัดเจน ฟังไปซักพักมันก็ชินครับ สายหูฟัง ตัวที่เสียบก็แข็งแรงดีครับ (สินค้ามาจากต่างประเทศ อาจใช้เวลาผ่านศุลกากรซักพักครับ)'}]},
#  {'Product_ID': 9,
#   'Link': 'https://www.lazada.co.th/products/edifier-direct-tws330-nb-wireless-bluetooth-noise-cancelling-earbuds-bluetooth-50-hybrid-anc-i2546267081.html',
#   'Name': 'Edifier Direct หูฟังบลูทูธ หูฟังไร้สาย TWS330 NB Wireless Bluetooth Noise Cancelling Earbuds ตัดเสียงรบกวน Bluetooth 5.0 Hybrid ANC',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿1,190.00',
#   'Original Price': '฿2,999.00',
#   'Score Average': '4.8',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย Anookul M.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '01 ก.ค. 2022',
#     'Comment': 'หูฟัง edifier tws 330 NB ที่สั่งไปช่วงลดราคาตอนนี้ได้รับสินค้าเรียบร้อยแล้วครับร้านค้าจัดส่งสินค้าให้ถือว่าไม่ช้าไม่เร็วของส่งมาจากจีนรอประมาณอาทิตย์กว่าๆเสียงดีครับแต่ต้องเลือกขนาดจุกยางให้เหมาะกับหูเสียงถึงจะออกมาดีไมค์ดีครับ'},
#    {'Review_Name': 'โดย S***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '05 มี.ค. 2022',
#     'Comment': 'จัดส่งมาจากจีนถือว่าระยะเวลากำลังดีไม่นานมาก ห่อมาแน่นหนา ตัวสินค้าไม่มีตำหนิใช้งานได้ดี ติดแค่ไม่มีประกันต้องรอลุ้นกันว่าจะมีปัญหาไหม'},
#    {'Review_Name': 'โดย Chalermchaiตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '12 ก.ค. 2022',
#     'Comment': 'หูฟังเสียงดี คุ้มค่ากับราคา วัสดุหุ้มหูฟังนุ่นนวล ชอบวัสดุที่ใช้ผลิต'},
#    {'Review_Name': 'โดย 4.4 4.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '26 ต.ค. 2022',
#     'Comment': 'ดีเลยครับแบตเตอรี่ใช้ได้ค่อยข้างนานตัวหูฟังมีน้ำหนักที่เบามากสีสันก็สวยด้วยผมชอบครับ'},
#    {'Review_Name': 'โดย N***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '12 ส.ค. 2022',
#     'Comment': 'คุณภาพสินค้าดีมากครับ คุ้มราคา 7xx มากครับ สินค้าแพ็ดดีมากครับ ทางร้านจัดส่งเร็วมากครับ พนักงานจัดส่งบริการดีมากครับ'}]},
#  {'Product_ID': 10,
#   'Link': 'https://www.lazada.co.th/products/edifier-p205-in-ear-earphone-build-in-mic-bass-i2682659914.html',
#   'Name': 'Edifier P205 in-ear Earphone Build-in Mic Bass พร้อมไมโครโฟนและระบบควบคุมแบบอินไลน์',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿299.00',
#   'Original Price': '฿399.00',
#   'Score Average': '4.9',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย ส***8ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '01 เม.ย. 2022',
#     'Comment': 'เสียงดีมากราคาไม่แพง จัดส่งจากจีนไวมากจริง ๆๆ'},
#    {'Review_Name': 'โดย พิษณุ ส.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '17 ก.พ. 2022',
#     'Comment': 'เสียงดี ชอบมาก'},
#    {'Review_Name': 'โดย สารทูล อ.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '3 สัปดาห์ก่อน',
#     'Comment': 'ของแถมงามๆๆๆๆๆๆๆๆๆๆๆๆๆ คือดีย์ๆๆๆๆๆๆๆๆๆๆๆไไๆ มากๆๆๆๆๆๆๆๆๆๆ ได้ไว สมราคาๆๆๆๆๆๆๆไไๆๆๆๆๆ'},
#    {'Review_Name': 'โดย ช***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '27 ต.ค. 2022',
#     'Comment': 'สินค้าจัดส่งเร็วมากค่ะ  ของแพ็คมาอย่างดี ทดลองใช้แล้วสินค้าใช้งานได้ดี คุ้มค่ากับราคามากค่ะ'},
#    {'Review_Name': 'โดย นาย ก.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '20 ส.ค. 2022',
#     'Comment': 'ได้เป็นของแถมจากซื้อหูฟัง ของแถมมาครบ กันกระแทกแน่นมาก ยังไม่ได้ลองใช้งาน แต่กล่องดูพรีเมี่ยมดี ขนส่งไวมาก มาจากต่างประเทศ โอเคมาก'}]},
#  {'Product_ID': 11,
#   'Link': 'https://www.lazada.co.th/products/edifier-to-u6-true-wireless-in-ear-headphones-bluetooth-earbuds-bluetooth-50-wireless-charge-cvc-call-noise-cancellation-dust-and-waterproof-ergonomically-design-fashion-color-i3605640275.html',
#   'Name': 'EDIFIER TO-U6+ True Wireless In-Ear หูฟังไร้สาย Headphones Bluetooth Earbuds Bluetooth 5.0 Wireless Charge CVC Call Noise Cancellation Dust and Waterproof Ergonomically Design Fashion Color',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿1,999.00',
#   'Original Price': '฿3,299.00',
#   'Score Average': '4.5'},
#  {'Product_ID': 12,
#   'Link': 'https://www.lazada.co.th/products/edifier-direct-x2-tws-earbuds-bluetooth-earphone-51-up-to-28hrs-playtime-game-mode-sports-ipx54-i2834101445.html',
#   'Name': 'Edifier Direct หูฟังบลูทูธ หูฟังไร้สาย X2 TWS Earbuds Bluetooth earphone 5.1 up to 28hrs playtime Game Mode Sports กันน้ำ IPX54 เบสหนัก',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿669.00',
#   'Original Price': '฿999.00',
#   'Score Average': '4.9',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย 0***5ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '18 ธ.ค. 2021',
#     'Comment': 'สินค้าดีมีคุณภาพแพ็คเกจสวยคุ้มราคา'},
#    {'Review_Name': 'โดย C***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '17 ก.พ. 2022',
#     'Comment': "I really like it. very good sounds , very comfortable. can do exercises without worrying about dropping from the ears. lag isn't noticable."},
#    {'Review_Name': 'โดย นนทวัฒน์ ร.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '09 ก.พ. 2022',
#     'Comment': 'การจัดส่งไวดีมาก ทางร้านรวดเร็วสั่งใันที่ 2 ก.พ. ส่ง 4 ก.พ. >ตปท.>ถึงมือวันที่ 9 ก.พ.\n\nคุณภาพสินค้าดี ล็อตใหม่ แกะกล่องพร้อมใช้งานทันที'},
#    {'Review_Name': 'โดย 9***4ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '21 ม.ค. 2022',
#     'Comment': 'ทุกคนคือมันโคตรดี ไม่เคยใช้มาก่อนเลยอยากลองใช้แบบราคาไม่แพงดู ปรากฎว่าดีมาก ถูกใจ น้ำหนักเบา อันเล็กพกพาสะดวก เสียงก็ดีเลิศไปเลยค่ะ'},
#    {'Review_Name': 'โดย ร***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '08 มี.ค. 2022',
#     'Comment': 'สินค้าคุณภาพดี \nไมค์:ใช้คุยโทรศัพท์ ใช้ประชุม ชัดเจน เก็บเสียงพูดได้ดี\nลำโพง: อาจจะไม่ได้มีเบสมากนัก เพราะเป็น buds แต่เสียงค่อนข้างครบ\nขนส่ง: ระยะเวลา 8 วัน เพราะส่งจากต่างประเทศ'}]},
#  {'Product_ID': 13,
#   'Link': 'https://www.lazada.co.th/products/edifier-direct-neobuds-pro-tws-i2860552730.html',
#   'Name': 'Edifier Direct Neobuds Pro TWS หูฟังบลูทูธ หูฟังไร้สาย หูฟังอินเอียร์ ตัดเสียงรบกวน พร้อมกล่องชาร์จ สามารถใช้กับไอโฟน แอนดรอยด์',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿3,980.00',
#   'Original Price': '฿5,999.00',
#   'Score Average': '4.9',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย Piphat C.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '01 เม.ย. 2022',
#     'Comment': 'สินค้าส่งรวดเร็วมาก แพ๊คมาดีมากตรงตามรูปดีเยี่ยมมากๆ'},
#    {'Review_Name': 'โดย J***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '07 มี.ค. 2022',
#     'Comment': 'ส่งไวเยี่ยมมาก\nคุ้มมากๆ'},
#    {'Review_Name': 'โดย Tawee S.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '08 ม.ค. 2022',
#     'Comment': 'เห็นรีวิวว่าสุดทุกด้าน เลยซื้อครับ ขนส่งดีมมากครับ เร็ว'},
#    {'Review_Name': 'โดย ธัชชัย ศ.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '12 ม.ค. 2022',
#     'Comment': 'ส่งช้าหน่อย ตัวกล่องเล็กลงแต่ของในได้เหมือนเดิม เดือนปีผลิต 12/21 น่าจะแก้ปัญหาของหูฟังมาระดับหนึ่ง ยังไม่ได้ลองเดี๋ยว ขอให้ไม่มีปัญหา'},
#    {'Review_Name': 'โดย C***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '20 ธ.ค. 2021',
#     'Comment': 'สินค้าถูกต้องตรงตามที่สั่ง สินค้าอยู่ในกล่องแพ็คมาอย่างดีมากๆ กล่องรวมทั้งหมด 4 ชั้น อุปกรณ์ และคู่มือครบถ้วน เสียงดีมาก ใช้งานได้ดี ของแถมครบถ้วน ใช้งานได้'}]},
#  {'Product_ID': 14,
#   'Link': 'https://www.lazada.co.th/products/edifier-tws1-pro-true-wireless-bluetooth-earbuds-v52-cvc80-ip65-i2545040776.html',
#   'Name': 'Edifier TWS1 Pro True Wireless Bluetooth Earbuds หูฟังไร้สาย หูฟังบลูทูธ V5.2 การตัดเสียงรบกวน CVC8.0 IP65 กันฝุ่นกันน้ำ',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿1,279.00',
#   'Original Price': '฿2,199.00',
#   'Score Average': '4.9',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย Raf S.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '17 ธ.ค. 2021',
#     'Comment': 'Nice quality 👏👍'},
#    {'Review_Name': 'โดย noomตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '08 พ.ย. 2021',
#     'Comment': 'จัดส่งไม่ช้าไม่เร็ว เชื่อมต่อง่าย เสียงดีมาก ระบบดี คุ้มค่าคุ้มราคา'},
#    {'Review_Name': 'โดย N***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '09 พ.ย. 2021',
#     'Comment': 'เสียงฟังชัดเจนค่ะ  ดีไซน์เก๋สวยคุณภาพดีมากค่ะ  สมราคา คุ้มมากค่ะ  ส่งไวกว่าที่คาดการณ์ไว้ค่ะ  ชอบมากเลยค่ะ'},
#    {'Review_Name': 'โดย Moxier.pตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '17 ก.ย. 2021',
#     'Comment': 'สินค้าแพคมาดีมาก อันน้ชิ้นที่ 3 แล้วหลังจากซื้อให้พ่อกับแฟนใช้เลยซื้อสีนี้มาใช้เองเพราะต ดใจเสียงดีมสก ราคาเป็นกันเอง สบายกระเป๋าสุดๆ แพคเกจสินค้าแน่นหนาแข็งแรงมากค่ะ เสียงนุ่มดี ตัดเสียงรบกวนภายนอกได้ดีมาก ชอบมากๆค่ะ'},
#    {'Review_Name': 'โดย m***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '13 ก.ย. 2022',
#     'Comment': 'รอไม่นานมาก 5วันก็มาถึงแล้ว ห่อมาอย่างดีเลย สีสวยมาก ลองใช้แล้วเชื่อมต่อง่ายดี แต่ว่ามีรอยดำๆตรงขอบนิดนึงแต่ไม่เป็นไร'}]},
#  {'Product_ID': 15,
#   'Link': 'https://www.lazada.co.th/products/edifier-mp230-10-50-sd-i3108618790.html',
#   'Name': 'Edifier MP230 ลำโพงบลูทูธพกพา ใช้งานได้นานถึง 10 ชั่วโมงต่อการชาร์จหนึ่งครั้ง มีการออกแบบที่เป็นคลาสสิกและมีฟูลเรนจ์ไดร์เวอร์บลูทูธ 5.0 ไมโคร SD',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿4,190.00',
#   'Original Price': '฿5,999.00',
#   'Score Average': '5.0',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย A***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '7 วันก่อน',
#     'Comment': 'ดีมากๆ ได้ของแถมเยอะ แล้วซื้อช่วงจัดโปรลดไปเยอะมากๆๆ เสียงก็ดี หน้าตาก็หล่อสุดๆ'},
#    {'Review_Name': 'โดย ฐ***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '2 สัปดาห์ก่อน',
#     'Comment': 'ชอบรูปลักษณ์ตั้งแต่แรก ไม่คิดว่าฝีมือและคุณภาพเสียงจะดีขนาดนี้\nแนะนำนะ \nราคายอมรับได้ ไม่เพง \nให้100คะแนน'},
#    {'Review_Name': 'โดย ****0ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '20 ก.ย. 2022',
#     'Comment': 'ชาร์จแล้วใช้งานยาวๆไปทนมาก เห็นครั้งแรกก็ติดใจในทันทีเลยซื้อสักสองสามชิ้นแล้วเอาไปให้เพื่อนดู เพื่อนบอกว่าหน้าตาและเนื้อสัมผัสสูง พอเอามาวางไว้ที่บ้านก็รสชาติดีขึ้น และคุณภาพเสียง ใช่ ฟังเพลงเพลินจริงๆ สีดูสดใสเหมือนในรูปฉันชอบลำโพงไม้'},
#    {'Review_Name': 'โดย z***Yตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '2 สัปดาห์ก่อน',
#     'Comment': 'รูปลักษณ์ภายนอก : บรรยากาศสะอาด ทำให้คนรักไม่ปล่อยตัว\nทำงานเกี่ยวกับคุณภาพ : ไม้ทำงานหนัก แต่รับประกันเสียงและระบบเสียงได้ว่า ยังช่วยยืดเวลาใ\nระบบเสียง : ระบบเสียงต่ำ มีความแข็งแกร่ง รักสุดยอด เสียงต่ำ ฟังเพลง เล่นเกม ดูหนัง\nง่ายต่อการติดตั้ง : สุดยอด  มีเคล็ดลับในการติดตั้งพาเนล และสามารถใช้งานได้สำหรับสายเค\nคุณลักษณะเพิ่มเติม : พร้อมรีโมทควบคุม คนขี้เกียจจะต้องเตรียมอาวุธ'},
#    {'Review_Name': 'โดย Warin H.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '6 วันก่อน',
#     'Comment': 'ของแถมเยอะมาก'}]},
#  {'Product_ID': 16,
#   'Link': 'https://www.lazada.co.th/products/edifier-stax-spirit-wireless-over-ear-headphone-hi-res-qualcomm-aptxadaptive-type-c-bluetooth-v52-with-full-size-plana-i3384322331.html',
#   'Name': 'EDIFIER STAX SPIRIT S3 หูฟังแบบครอบหูตัดเสียงรบกวน Wireless Over Ear Headphone Hi-Res รองรับ Qualcomm® aptX™Adaptive Type-C เชื่อมต่อด้วย Bluetooth V5.2 with FULL-SIZE ไดร์เวอร์ PLANA',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿12,599.00',
#   'Original Price': '฿14,699.00',
#   'Score Average': '5.0',
#   'Num of Reviews': 4,
#   'Review': [{'Review_Name': 'โดย พ***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '23 มิ.ย. 2022',
#     'Comment': 'ถูกใจวัยรุ่น ใสนิ่มหูมาก ตัดเสียงรบกวนดี เสียงชัดมาก รวมๆแล้วดีมากคับ สุดยอดคับ'},
#    {'Review_Name': 'โดย สมศักดิ์ ต.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '16 ก.ค. 2022',
#     'Comment': 'ของมาจากจีน ใช้เวลาส่ง7 วันถือว่าเร็วครับ\nใส่กล่อง พร้อมฟองน้ำช่วยกันกระแทกได้ดีมาก\n ได้ของแถมเป็นหูฟังตามรูป\nส่วนตัวหูฟัง เสียงดี แต่ใส่แล้วร้อน \nเปลี่ยนตัวearpad เป็นแบบผ้าช่วยได้'},
#    {'Review_Name': 'โดย ภ***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '14 ก.ย. 2022',
#     'Comment': 'ชอบมาก ดีมาก เสียงละเอียด นุ่มนวล เพลินใจ วัสดุที่ใช้ก็ดีสมราคา การเปลี่ยนหูก็ไม่อยาก แอพที่โหลดมาใช้คู่กันใช้ง่ายสะดวก หูฟังมีน้ำหนักอยู่เหมือนกัน แต่ครอบแบบฟูลไซส์ได้นุ่มสบาย\nทางร้านแพ็คมาแน่นหนา ตัวแพ็คเก็จของหูฟังดี'},
#    {'Review_Name': 'โดย วรกฎ ไ.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '17 ก.ย. 2022',
#     'Comment': 'สินค้าส่งรวดเร็ว หีบห่ออย่างดี คุณภาพเสียงยังไม่โอเค เสียงแห้ง flat เกินไป ขาดความละเมียดละไม กับเนื้อหนัง เสียงกลางบางครั้งยังโด่งๆเสียดหูอยู่'}]},
#  {'Product_ID': 17,
#   'Link': 'https://www.lazada.co.th/products/edifier-direct-x3-wireless-earbuds-bluetooth-50-cvc80-ipx5-i2566645561.html',
#   'Name': 'Edifier Direct X3 Wireless Earbuds หูฟังไร้สาย หูฟังบลูทูธ Bluetooth 5.0 การตัดเสียงรบกวน cVc8.0 IPX5 กันฝุ่นและกันน้ำ',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿799.00',
#   'Original Price': '฿1,499.00',
#   'Score Average': '4.9',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย วิวัฒนา อ.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '19 พ.ย. 2021',
#     'Comment': 'รูปลักษณ์กึ่งพรีเมี่ยม กึ่งบัดเจท แต่เสียงเกินตัวมาก อาจไม่กระหึ่มบึ้มเบิ้มไรมาก แต่ก็ไม่รกจนตัดกันในย่านเสียง\nในตัวสินค้าได้รับใน 9 วัน ถือว่าปกติ'},
#    {'Review_Name': 'โดย MaiLy A.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '18 ส.ค. 2021',
#     'Comment': 'จัดส่งไว สินค้าเเพ็คมาอย่างดี คุ้มค่ากับราคา\nตัวกล่องเก็บหูฟังมีขนาดเล็ก สะดวกกับการพกพา เสียงดี'},
#    {'Review_Name': 'โดย ภ***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '18 ส.ค. 2022',
#     'Comment': 'สีสวยน่ารักมาก ใช้งานได้ปกติ เชื่อมต่อง่าย'},
#    {'Review_Name': 'โดย kungnuตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '04 มิ.ย. 2022',
#     'Comment': 'ใช้งานได้ดีมาก ลองแล้ว ของดีราคาถูกแนะนำเลยครับ คุณภาพเกินราคาแล้วใครหาอยู่แนะนำครับ ราคาก็ดี ส่งของไวมากครับไม่เกิน5วันจากต่างประเทศ ถือว่าเร็วมากๆๆแล้วคับ'},
#    {'Review_Name': 'โดย จารุวิชญ์ ส.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '14 เม.ย. 2022',
#     'Comment': 'รับของแล้วครับรีวิวให้ช้าเพราะกลับต่างจังหวัด ของส่งจากต่างประเทศถึงตามกำหนดเสียงดีโดยรวมพอใจครับ'}]},
#  {'Product_ID': 18,
#   'Link': 'https://www.lazada.co.th/products/edifier-w800bt-plus-bluetooth-on-ear-headset-qualcomm-aptx-40mm-driver-55-i2692516234.html',
#   'Name': 'Edifier หูฟังคาดหัว หูฟังครอบหู หูฟังบลูทูธ W800BT Plus หูฟังครอบหู Bluetooth On-Ear Headset Qualcomm aptX 40mm Driver ใช้งานได้ 55 ชั่วโมง',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿1,179.00',
#   'Original Price': '฿1,890.00',
#   'Score Average': '4.9',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย 0***2ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '27 ก.ย. 2021',
#     'Comment': 'สินค้าได้รับการหีบห่อมาดีมากๆ กันกระแทกเต็มกล่อง หูฟังคุณภาพดี เสียงเบสหนักแน่น เสียงใสก็ชัดเจน และที่สำคัญคือใส่ไม่เจ็บหู เพราะขนาดฟองน้ำที่หุ้มมาค่อนข้างใหญ่แบบครอบใบหูได้เลย ทำให้ใส่ได้นาน แถมลองใช้แล้วแบตอึดมาก ประทับใจครับ ไว้มีโอกาสจะกลับมาซื้อใหม่'},
#    {'Review_Name': 'โดย 0***9ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '11 ต.ค. 2021',
#     'Comment': 'ได้รับสินค้าแล้ว น่าใช้มากค่ะ สินค้าแพคมาอย่างดีทั้งภายนอกและภายในกล่องค่ะ ไว้จะอุดหนุนต่อๆไปนะคะ'},
#    {'Review_Name': 'โดย P***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '2 สัปดาห์ก่อน',
#     'Comment': 'ได้รับสินค้าเรียบร้อยแล้วค่ะ รอของประมาณ9วัน ปรับขยายได้ปกติ วัสดุภายนอกเป็นพลาสติก น้ำหนักเบา แต่เพราะเบาเลยดูเหมือนจะโงนเงนไปหน่อย ที่ครอบหูนุ่มดีค่ะ ยังกันเสียงรอบนอกไม่ได้100เปอแต่เราไม่ได้ซีค่ะ ลองใช้แล้วแบบไวเลทเราว่าเสียงเพลงมันออกทุ้มๆทื่อๆไปมากอยู่ (หรือเราปรับไม่เป็น) ส่วนระดับความดัง: ต้องเปิดดังๆถึงจะได้ยิน แต่เราไม่ชอบฟังเสียงดังมากขนาดนั้น แล้วพอเปิดเบา(ระดับ2ขีดในมือถือ)ก็เหมือนติดเบา+เสียงทุ้มอยู่แล้ว เลยเหมือนไม่ค่อยได้ยิน /แต่ถ้าใช้เสียบสายต่อคอม เสียงชัดแจ๋วกว่ากันมากๆค่ะ'},
#    {'Review_Name': 'โดย น***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '4 สัปดาห์ก่อน',
#     'Comment': 'ส่งเร็วมากๆ \nราคาดี คุณภาพดี\nวัสดุเบา เเต่ไม่ก๊อกแก๊ก \nถือว่าจับแล้วรู้สึกวัสดุแข็งแรงดี\nลองฟังแล้วรู้สึกเสียงดี ฟังได้ชัดเจนดี\nเที่ยบกับราคาและคุณภาพ จัดว่าดีมาก'},
#    {'Review_Name': 'โดย Chibi R.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '01 ส.ค. 2022',
#     'Comment': 'สินค้าแท้สวยตรกปก ห่อสินค้ากันกระแทกอย่างดี สั่ง 2 ชิ้น แต่มาคนล่ะขนส่ง สินค้า 1 ชิ้น มีปัญหา ไม่ได้ยินข้างหนึ่ง แต่สินค้ามีประกัน ทางร้านตอบแชทเร็ว ส่งเคลมตัวใหม่มาให้ รอสินค้าไม่นานเท่าไหร่ บริการดีมากคะ'}]},
#  {'Product_ID': 19,
#   'Link': 'https://www.lazada.co.th/products/edifier-hecate-gx07-lhdc-anc-dual-ambient-noise-cancelling-microphone-i2708391767.html',
#   'Name': 'EDIFIER HECATE GX07 สุดยอดหูฟังเกมมิ่งไร้สาย ดีเลย์น้อย มิติเสียงระดับเทพ, การตัดเสียงรบกวนแบบไฮบริด LHDC ANC Dual Ambient Noise Cancelling Microphone',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿3,389.00',
#   'Original Price': '฿6,299.00',
#   'Score Average': '4.9',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย 0***4ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '17 ก.ย. 2022',
#     'Comment': 'ดีมากครับ ส่งเร็วกว่าที่กำหนดอีก ได้ของจริงครับ แนะนำร้านนี้เลยครับ ได้ของจริงๆ ขอบคุณสำหรับบริการดีๆ'},
#    {'Review_Name': 'โดย บุญดี ค.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '29 ก.ย. 2021',
#     'Comment': 'สินค้าดี มีตัดเสียงรบกวน เงียบดีจริงๆ ทดสอบใช้โทรศัพท์เสียงชัดเจนมาก ใช้ฟังเพลงเสียงดีมาก รูปทรงทันสมัยสวยงาม มีแอปรองรับ เสียอย่างเดียว หลังจากสั่งได้รับสินค้า ราคาลดลงซะงั้น น่าจะมีสีอื่นให้เลือกด้วยก็จะดีมาก'},
#    {'Review_Name': 'โดย จ***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '14 พ.ย. 2021',
#     'Comment': ''},
#    {'Review_Name': 'โดย Aom I.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '22 พ.ย. 2021',
#     'Comment': ''},
#    {'Review_Name': 'โดย ป๋า ม.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '23 เม.ย. 2022',
#     'Comment': 'ส่งวัยมากครับของแพ็กมาดี'}]},
#  {'Product_ID': 20,
#   'Link': 'https://www.lazada.co.th/products/edifier-neobuds-s-wireless-bluetooth-earbuds-qualcomm-snapdragon-sound-game-mode-with-hybrid-active-noise-cancelling-i3689529335.html',
#   'Name': 'EDIFIER Neobuds S หูฟัง ไร้สาย Wireless Bluetooth Earbuds หูฝังบลูทูธ ตัดเสียงรบกวน Qualcomm Snapdragon Sound Game mode with Hybrid Active Noise Cancelling สามารถใช้กับไอโฟน แอนดรอยด์',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿5,509.00',
#   'Original Price': '฿6,990.00',
#   'Score Average': '4.9',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย อ***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '15 ก.ย. 2022',
#     'Comment': 'สินค้ารอนานครับเพราะไม่ได้ส่งจากประเทศไทย แต่ซื้อช่วงโปรมีส่งของแถมมาให้ด้วย ลองใช้นิดหน่อยถือว่าดีครับปรับเลือกได้หลายแบบเสียงดีตัดเสียงรบกวนได้จริง ครับ'},
#    {'Review_Name': 'โดย พ***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '23 มิ.ย. 2022',
#     'Comment': 'แพ็กมาดีมาก ขนส่งใจดี สอนค้าคุณภาพ ใช้เลย ไม่ผิดหวัง แบบว่าเสียงดีมาก ไม่ว่าจะเป็นสินค้าครบรอบ 25 ปี ฝีมือดี ดูเท่  จับมือไว้ รู้สึกดีมาก ไฟข้างกล่องหูฟังก็หล่อมาก ที่อุดหูมีครบ7ขนาด ชอบอันนี้มาก ก่อนซื้อมา ได้อ่านการเปรียบเทียบหลายหลายอย่าง ลองมาใช้งานและก็ไม่ทำให้ผมผิดหวัง ได้ความจิงใจครบรอบ 25 ปีของ Edifier คุณภาพเสียงดีเกินคาด เบสทรงพลัง หน่วยเหล็กที่เคลื่อนที่ได้มีความละเอียดเสียงสูงที่มีความถี่สูง ให้ความรู้สึกเหมือนไม่ได้ใส่หูฟังเลย ฟังก์ชั่นลดเสียงรบกวนอย่างมีประสิทธิภาพมาก เวลาใช้ด้วยAPP  ประสบการณ์จะดีขึ้น'},
#    {'Review_Name': 'โดย Arun B.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '18 ส.ค. 2022',
#     'Comment': 'คุณภาพเสียงดีมากแบตอึดรอดูระยะยาวเรื่องความคงทนครับ'},
#    {'Review_Name': 'โดย BIGตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '12 ก.ย. 2022',
#     'Comment': 'ส่งจากจีนแต่เร็วมาก'},
#    {'Review_Name': 'โดย สุรพันธ์ จ.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '26 ส.ค. 2022',
#     'Comment': 'ส่งไวมาก เสียงจัดอยู่ว่าดี แต่ขาดความอิ่มของเสียงไปนิดหน่อย แต่เบส แหลมไปได้สุดดีชอบครับ เรื่องไมค์ตัดเสียงได้ดี'}]},
#  {'Product_ID': 21,
#   'Link': 'https://www.lazada.co.th/products/edifier-w240tn-tws-ai-53-android-ios-i3904681802.html',
#   'Name': 'Edifier W240TN TWS หูฟังไร้สายบลูทูธหูฟังไร้สาย AI ตัดเสียงรบกวนบลูทูธ 5.3 กันน้ำพร้อมไมโครโฟนโหมดเกมชาร์จเร็วสำหรับ Android และ IOS',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿2,699.00',
#   'Original Price': '฿3,590.00',
#   'Score Average': '5.0',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย Thapanee B.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '12 ก.ย. 2022',
#     'Comment': 'ดีมากกกก\nแพคมาดีเวอร์\nจัดส่งไวด้วย\n1แถม1 ด้วย\nคุณภาพดีมากกกกก\nชอบมากกกก 😍😍😍😍'},
#    {'Review_Name': 'โดย a***pตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '19 ก.ย. 2022',
#     'Comment': 'เป็นของแถมแต่ดูไม่กิ๊กก๊อกเลยค่ะ ผ้าหนา ดูแพงมาก งงๆนิดหน่อยที่ส่งมาคนละแพคกับหูฟัง แต่ก็มาถึงวันเดียวกันพอดี คุ้มค่ามากๆค่ะ'},
#    {'Review_Name': 'โดย ดีสมาน ส.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '12 ก.ย. 2022',
#     'Comment': 'แพ็คสินค้ามาอย่างดี สินค้าถูกต้องตรงตามที่สั่ง\nการจัดส่งรวดเร็ว พนักงานมีการโทรมาแจ้งล่วงก่อนที่จะส่งสินค้า\nของแถมถูกใจมากครับ'},
#    {'Review_Name': 'โดย รักชาติ แ.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '13 ต.ค. 2022',
#     'Comment': 'ดูดีครับ สวยงาม เสียงร้องฟังอยู่ ตอนนี้ก็ดี ครบทุกย่านความถี่เพราะทั้งร็อก สามช่า อะคูสติก จัดว่าดีมากเลย แต่ใส่ได้ไม่ค่อยแน่น จะเอาไปวิ่งกลัวหลุดหายครับ ชอบๆๆๆครับ'},
#    {'Review_Name': 'โดย ****0ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '10 ก.ย. 2022',
#     'Comment': 'W240TN：ได้รับของก็รีบเปิด ไม่ทำให้ผมผิดหวังจริงๆครับ คุณภาพดีมาก สวย \nฝีมือ：ฝีมือได้รับการอัพเกรดเมื่อเทียบกับรุ่นก่อนและรูปร่างก็มีเอกลักษณ์มากและโครงสร้างหูฟังก็ดีมาก\nเสียง：คุณภาพเสียงดีมาก แจ่มใส ไม่มีเสียงรบกวน ฟังเพลงเพราะมาก\nความสบาย：หูฟังเท่ากับหูพอดี เบามากและใส่สบาย\nเวลาใช้งาน：เตอรี่ก็โอเค ชาร์จเร็วนครับ'}]},
#  {'Product_ID': 22,
#   'Link': 'https://www.lazada.co.th/products/edifier-direct-w280nb-wireless-sports-headphones-with-active-noise-cancellation-i2924751094.html',
#   'Name': 'Edifier Direct W280NB ชุดหูฟังบลูทูธ หูฟังไร้สาย สำหรับเล่นกีฬา หูฟังตัดเสียงรบกวน Wireless Sports Headphones with Active Noise Cancellation',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿1,569.00',
#   'Original Price': '฿2,399.00',
#   'Score Average': '4.9',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย J***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '13 ก.ย. 2022',
#     'Comment': 'สินค้าจัดส่งถือว่ารวดเร็วมาก ๆ สินค้าหีบห่อแน่นหนามิดชิด มีที่กันกระแทกให้มาอย่างดี สินค้าได้ตรงตามที่สั่ง เสียงกาะหึ่มดี ใส่ออกกำบังกทยไม่มีหลุดเลย'},
#    {'Review_Name': 'โดย S***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '4 วันก่อน',
#     'Comment': 'Arrived and happy buyer.\nFirst order was cancelled. This is my second round order\nThankfully it arrived.\nGood quality.\nRecommended seller'},
#    {'Review_Name': 'โดย Song N.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '15 ก.ย. 2022',
#     'Comment': 'ดีครับแบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบบ'},
#    {'Review_Name': 'โดย 0***4ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '13 ก.ย. 2022',
#     'Comment': 'สวย ได้ของเร็วดี'},
#    {'Review_Name': 'โดย ทศพร พ.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '20 ก.ย. 2022',
#     'Comment': 'ได้แถมมากับ Neobuds Pro ซึ่งไม่อยากได้เลย คิดว่าเป็นของไม่ดี แต่พอได้ใช้แล้วดีกว่าที่คิดมาก คุณภาพเสียงกลางๆค่อนข้างดี วอลลุ่มเยอะกว่าหูฟังทั่วไปอย่างน้อย 1 ระดับ เบสเยอะเหมาะกับการใส่ Work out นอกสถานที่ และที่สำคัญคือใส่แล้วสบาย ไม่หลวม ไม่หลุดหรือรู้สึกเมื่อย แบตอึดมาก สามารถใส่ทำกิจกรรมต่างๆได้ทั้งวันโดยไม่ต้องชาร์จ เคยใช้ยาว 10 ขม.พร้อม ANC แบตยังเหลืออีก 10%'}]},
#  {'Product_ID': 23,
#   'Link': 'https://www.lazada.co.th/products/edifier-to-u7-pro-true-wireless-noise-cancellation-earbuds-18-hours-bluetooth-53-bluetooth-earbuds-waterproof-game-mode-i4043472695.html',
#   'Name': 'Edifier TO-U7 Pro True Wireless Noise Cancellation Earbuds 18 hours หูฟังไร้สาย หูฟังบลูทูธ Bluetooth 5.3 Bluetooth Earbuds Waterproof Game Mode',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿3,899.00',
#   'Original Price': '฿4,890.00',
#   'Score Average': '0'},
#  {'Product_ID': 24,
#   'Link': 'https://www.lazada.co.th/products/edifier-to-u2-mini-true-wireless-earbuds-bluetooth-51-up-to-25-hours-led-display-ip54-i3605555796.html',
#   'Name': 'Edifier TO-U2 mini True Wireless Earbuds หูฟังไร้สาย หูฟังบลูทูธ Bluetooth 5.1 up to 25 hours LED Display IP54 กันฝุ่นกันน้ำ',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿1,679.00',
#   'Original Price': '฿2,399.00',
#   'Score Average': '4.9',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย 6***5ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '14 พ.ค. 2022',
#     'Comment': 'ได้รับสินค้าแล้วค่ะ สีสวยถูกใจมากค่ะ คนส่งบริการดี โทรก่อนมาด้วย ชอบมากๆเลยค่ะ'},
#    {'Review_Name': 'โดย ****0ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '07 พ.ค. 2022',
#     'Comment': 'หูฟังดูดีจริงๆและรูปลักษณ์ที่น่ารักมาก จัดส่งได้อย่างรวดเร็วทั้งสองข้างของหูฟังสามารถใช้งานได้ตามปกติคุณภาพเสียงดีไม่มีความเสียหายและเสียงดีมากๆสั่งเป็นของขวัญให้กับเพื่อน ๆ ชอบเป็นพิเศษ และที่สําคัญที่สุดคือ หูฟังนี้ ทําให้ผม wink！！！'},
#    {'Review_Name': 'โดย pornsopa K.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '10 มิ.ย. 2022',
#     'Comment': 'สินค้าสวยมาๆค่ะคุณภาพสินค้าดีมากๆเชื่อมต่อง่ายย'},
#    {'Review_Name': 'โดย K***Rตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '16 ก.ย. 2022',
#     'Comment': 'เสียงดี น่ารักมากเลยค่ะ'},
#    {'Review_Name': 'โดย aoyzaตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '10 ก.ย. 2022',
#     'Comment': 'ร้านค้าส่งเร็วมากแม้จะมาจากต่างประเทศ เสียใจซื้อก่อน 9.9 ไม่งั้นจะได้ลดไปอีกหลายร้อย ได้มาราคาพันสามปลายๆ ได้เงินคืนอีกนิดหน่อย  ทางร้านไม่แถมถุงใส่หูฟังให้เลยซึ่งจริงๆควรจะแถม ก็เลยกดซื้อเองปรากฏว่าจ่าย 0 บาทโอเคให้อภัย 100% สินค้าน่ารักเกินปุยมุ้ยสีหวานแหววมาก แต่เรื่องเสียงคงต้องเบิร์นสัก50 ชม\nถึงจะทราบ ตอนแรกฟังนี้เสียงยังธรรมดานะ เบสเบามาก ถือว่าพอใช้ตามราคา'}]},
#  {'Product_ID': 25,
#   'Link': 'https://www.lazada.co.th/products/edifier-wh500-type-c-fast-charging-bluetooth-v52-i2546231392.html',
#   'Name': 'Edifier WH500 หูฟังคาดหัว หูฟังไร้สาย ตัดเสียงรบกวน Type-C Fast Charging Bluetooth V5.2',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿1,719.00',
#   'Original Price': '฿2,899.00',
#   'Score Average': '4.9',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย torsak W.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '17 ต.ค. 2022',
#     'Comment': 'ได้รับเป็นของแถม  จากการซื้อหูฟัง  ด้านนอกกันน้ำได้ระดับหนึ่ง  ด้านในนุ่มๆ  ทำให้ตัวเคสหูฟัง  ไม่เป็นรอยขีดข่วน'},
#    {'Review_Name': 'โดย N***nตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '2 สัปดาห์ก่อน',
#     'Comment': 'น้องเสียงดีมากฟังเพลงครั้งแรกแบบตาวาว ถ้าเล่นเกมเปิดโหมดเกมในแอปของเขาเสียงจะไม่ดีเลย์เลย แต่ถ้าเปิดโหมดฟังเพลงแล้วเล่นเกมเสียงจะดีเลย์นิดหน่อย น้องนุ่มๆใส่นานๆไม่เจ็บหูแต่ถ้าคนไม่เคยใส่แล้วยังไม่ชินช่วงแรกๆจะหนักหัวนิดหน่อย อันนี้รีวิวจริงได้ของจริง สั่งเองไม่มีสแตนอินนะ แต่ถุงผ้าที่บอกจะมีแถมไม่มีมาให้นะแต่มปรคงไม่ได้ใช้อยู่แล้ว ซื้อตอน 11.11 ได้มา 1,199 เอง คุ้มสุด'},
#    {'Review_Name': 'โดย เ***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '14 ก.ย. 2021',
#     'Comment': 'ดี\nน่าใช้\nไม่ช้าจากจีน\nหูนิ่มมาก\nฟังเสียงดี หูไม่ถึง\nพอใจกับราคา 9.9\nค่ารักษาหู แพงมาก\nลงทุนซื้อมาใส่'},
#    {'Review_Name': 'โดย นพดล ท.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '14 ก.ย. 2021',
#     'Comment': 'ถือว่าเสียงใช้ได้ในราคานี้ ส่วน บลูทูธ apt-x ให้เสียงดีกว่าสายaux ใครเล่น dac amp คงต้องขยับซื้อหูฟังแพงๆดีกว่า\n\nโปร 9.9 ได้มา 900 บาท แต่อย่าคิดว่าถูกที่สุดเพราะยังมีอีกร้านที่ชื่อใกล้เคียงกัน ราคาแค่ 788 บาท เอง หลังหักกันไป เจ็บแปบๆๆๆๆๆๆๆ'},
#    {'Review_Name': 'โดย ****0ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '03 พ.ย. 2022',
#     'Comment': 'มาแล้วสีขาวกูกใจมากเสียงดี'}]},
#  {'Product_ID': 26,
#   'Link': 'https://www.lazada.co.th/products/edifier-direct-tws-nb2-pro-wireless-bluetooth-noise-cancelling-earbuds-ip65-i2545665467.html',
#   'Name': 'Edifier Direct TWS NB2 Pro Wireless Bluetooth Noise Cancelling Earbuds หูฟังบลูทูธ หูฟังไร้สาย ตัดเสียงรบกวน กันฝุ่นและกันน้ำ IP65',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿2,319.00',
#   'Original Price': '฿3,999.00',
#   'Score Average': '4.9',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย จ***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '10 ก.พ. 2022',
#     'Comment': 'แพคของกันกระแทกอย่างดี เสียงดี คุ้มมากจ้า'},
#    {'Review_Name': 'โดย P***.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '2 สัปดาห์ก่อน',
#     'Comment': 'รอของไม่นานเลยค่ะ ประมาณ 1 สัปดาห์ทั้งๆที่ส่งมาจากจีน พัสดุห่อซองบางๆมาแต่ไม่มีอะไรเสียหาย กล่องหูฟังดูดีมาก สมราคาค่ะ ลองฟังดูแล้วเบสหนักมาก เหมาะกับเพลงร็อคจังหวะสนุกๆหน่อย เอาไปใส่ออกกำลังกายแล้วฟินมาก ชอบๆ แต่จุกหูฟังที่ให้มาไม่ค่อยพอดีหูเท่าไรค่ะเพราะเราหูเล็กเลยใช้ของ spinfit ข้อเสียคือมันชาร์จไม่ได้ต้องถอดจุกก่อนแล้วค่อยเก็บหูฟัง'},
#    {'Review_Name': 'โดย ดวงฤทัย อ.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '29 ส.ค. 2022',
#     'Comment': 'แพคมาอย่างดี รอสินค้าประมาณ 5 วัน ของดีจริงๆ'},
#    {'Review_Name': 'โดย B***7ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '25 ก.ค. 2022',
#     'Comment': 'ดีมาก โคดคุ้มมมมมม'},
#    {'Review_Name': 'โดย อริสรา ไ.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '17 มิ.ย. 2022',
#     'Comment': 'ได้รับสินค้าแล้วนะคะ คุณภาพของสินค้าดีมาก ความคุ้มค่าดีมาก แพคสินค้ามาโอเคมากเลย ความรวดเร็วในการจัดส่งดี ส่งจากจีน รอประมาณ3-4วันของก็ถึงแล้ว'}]},
#  {'Product_ID': 27,
#   'Link': 'https://www.lazada.co.th/products/edifier-cc200-headset-wireless-up-to-64-hours-dual-mic-bluetooth-v50-i3411687857.html',
#   'Name': 'Edifier CC200 Headset Wireless หูฟังบลูทูธ พร้อมไมโครโฟนตัดเสียงรบกวน ที่คาดผมแบบปรับได้สำหรับ ออฟฟิศ เรียนออนไลน์ up to 64 Hours Dual MIC Bluetooth V5.0',
#   'Status': 'Sale',
#   'Scan Status': 'Non-Complete',
#   'Sell Price': '฿1,739.00',
#   'Original Price': '฿2,290.00',
#   'Score Average': '4.7',
#   'Num of Reviews': 5,
#   'Review': [{'Review_Name': 'โดย kitisakตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '15 มิ.ย. 2022',
#     'Comment': 'สวยงาม ส่งเร็วกว่าที่คาดการ'},
#    {'Review_Name': 'โดย A***�ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '03 มิ.ย. 2022',
#     'Comment': 'แพ๊คสินค้ามาดีมากค่ะ ยังไม่ได้ลองใช้'},
#    {'Review_Name': 'โดย ****0ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '05 พ.ค. 2022',
#     'Comment': 'ส่งไว แพ็คมาอย่างดี สินค้าตรงปก เสียดีใช้ได้ถูกใจร้านนี้เลย'},
#    {'Review_Name': 'โดย ศรชัย ท.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '15 ชั่วโมงก่อน',
#     'Comment': 'ตรงตามรูป คุณภาพดีมาก รอทดสอบเรื่องตัดเสียงรบกวนพรุ้นนี้'},
#    {'Review_Name': 'โดย scb N.ตรวจสอบว่ามีการสั่งซื้อแล้ว',
#     'Rating_Time': '4 วันก่อน',
#     'Comment': 'สินค้าดี แต่รอนานไปนิดเพราะส่งจาก ตปท ตอนกดซื้อบอกมีของแถม แต่ไม่ได้ส่งมาด้วยนะคะ'}]}]

# %%
json_string = json.dumps(product_list, ensure_ascii=False)
print(json_string)
# Out:
# [{"Product_ID": 1, "Link": "https://www.lazada.co.th/products/edifier-direct-edifier-x5-wireless-earbuds-bluetooth-50-ip55-i2544667414.html", "Name": "Edifier Direct หูฟังบลูทูธ หูฟังไร้สาย Edifier X5 Wireless Earbuds Bluetooth 5.0 ลดเสียงรบกวนจากการโทร IP55 กันฝุ่นและกันน้ำ", "Status": "Sale", "Scan Status": "Non-Complete", "Sell Price": "฿869.00", "Original Price": "฿1,699.00"}, {"Product_ID": 2, "Link": "https://www.lazada.co.th/products/edifier-tws200-plus-true-wireless-stereo-earbuds-qualcomm-aptx-bluetooth-52-up-to-24hrs-playtimenoise-cancellation-i3284890319.html", "Name": "Edifier TWS200 Plus True Wireless Stereo Earbuds หูฟังไร้สาย Qualcomm AptX Bluetooth 5.2 up to 24hrs playtime Noise Cancellation", "Status": "Sale", "Scan Status": "Non-Complete", "Sell Price": "฿1,449.00", "Original Price": "฿1,999.00", "Score Average": "4.8", "Num of Reviews": 20, "Review": [{"Review_Name": "โดย PomPam😽🐾ตรวจสอบว่ามีการสั่งซื้อแล้ว", "Rating_Time": "14 พ.ค. 2022", "Comment": "ได้รับสินค้าเรียบร้อยค่ะ ส่งจากจีนแต่ได้ไวมากๆ แพคมาอย่างดีสินค้าไม่เสียหาย สินค้าตรงปก ของดีเสียงฟังชัดแจ๋ว ชอบมากๆ ค่ะ แนะนําร้านนี้ ราคาดีคุ้มค่ามาก"}, {"Review_Name": "โดย ชญานิษฎ์ตรวจสอบว่ามีการสั่งซื้อแล้ว", "Rating_Time": "14 พ.ค. 2022", "Comment": "แพคกิ้งดีมากกกกกกั้นกระแทกหลายชั้นเลยชอบมากค่ะ\nลองฟังแล้วเสียงเพราะมากสั่งครั้งแรกถูกใจสุดๆเลยค่ะ\nพกพาง่ายชาร์ตแบตแปปเดียวเต็มสีดำสวยสุดๆเลย\nโดยรวมถูกใจมากค่ะ"}, {"Review_Name": "โดย 8***5ตรวจสอบว่ามีการสั่งซื้อแล้ว", "Rating_Time": "09 พ.ค. 2022", "Comment": "ส่งของมาเร็ว แพ็คมาดี ใช้งานง่าย"}, {"Review_Name": "โดย 8***8ตรวจสอบว่ามีการสั่งซื้อแล้ว", "Rating_Time": "09 พ.ค. 2022", "Comment": "แนะนำเลยค่ะ พกพาสะดวก น่ารัก คุณภาพเยี่ยม ❤️❤️❤️"}, {"Review_Name": "โดย ศศิญา ไ.ตรวจสอบว่ามีการสั่งซื้อแล้ว", "Rating_Time": "09 พ.ค. 2022", "Comment": "กล่องแพ็คมาอย่างดี มีกันกระแทก แพ็คเก็จดีงาม ถูกใจสุดๆๆๆๆๆๆๆๆๆๆๆๆๆๆๆ"}, {"Review_Name": "โดย PomPam😽🐾ตรวจสอบว่ามีการสั่งซื้อแล้ว", "Rating_Time": "14 พ.ค. 2022", "Comment": "ได้รับสินค้าเรียบร้อยค่ะ ส่งจากจีนแต่ได้ไวมากๆ แพคมาอย่างดีสินค้าไม่เสียหาย สินค้าตรงปก ของดีเสียงฟังชัดแจ๋ว ชอบมากๆ ค่ะ แนะนําร้านนี้ ราคาดีคุ้มค่ามาก"}, {"Review_Name": "โดย ชญานิษฎ์ตรวจสอบว่ามีการสั่งซื้อแล้ว", "Rating_Time": "14 พ.ค. 2022", "Comment": "แพคกิ้งดีมากกกกกกั้นกระแทกหลายชั้นเลยชอบมากค่ะ\nลองฟังแล้วเสียงเพราะมากสั่งครั้งแรกถูกใจสุดๆเลยค่ะ\nพกพาง่ายชาร์ตแบตแปปเดียวเต็มสีดำสวยสุดๆเลย\nโดยรวมถูกใจมากค่ะ"}, {"Review_Name": "โดย 8***5ตรวจสอบว่ามีการสั่งซื้อแล้ว", "Rating_Time": "09 พ.ค. 2022", "Comment": "ส่งของมาเร็ว แพ็คมาดี ใช้งานง่าย"}, {"Review_Name": "โดย 8***8ตรวจสอบว่ามีการสั่งซื้อแล้ว", "Rating_Time": "09 พ.ค. 2022", "Comment": "แนะนำเลยค่ะ พกพาสะดวก น่ารัก คุณภาพเยี่ยม ❤️❤️❤️"}, {"Review_Name": "โดย ศศิญา ไ.ตรวจสอบว่ามีการสั่งซื้อแล้ว", "Rating_Time": "09 พ.ค. 2022", "Comment": "กล่องแพ็คมาอย่างดี มีกันกระแทก แพ็คเก็จดีงาม ถูกใจสุดๆๆๆๆๆๆๆๆๆๆๆๆๆๆๆ"}, {"Review_Name": "โดย PomPam😽🐾ตรวจสอบว่ามีการสั่งซื้อแล้ว", "Rating_Time": "14 พ.ค. 2022", "Comment": "ได้รับสินค้าเรียบร้อยค่ะ ส่งจากจีนแต่ได้ไวมากๆ แพคมาอย่างดีสินค้าไม่เสียหาย สินค้าตรงปก ของดีเสียงฟังชัดแจ๋ว ชอบมากๆ ค่ะ แนะนําร้านนี้ ราคาดีคุ้มค่ามาก"}, {"Review_Name": "โดย ชญานิษฎ์ตรวจสอบว่ามีการสั่งซื้อแล้ว", "Rating_Time": "14 พ.ค. 2022", "Comment": "แพคกิ้งดีมากกกกกกั้นกระแทกหลายชั้นเลยชอบมากค่ะ\nลองฟังแล้วเสียงเพราะมากสั่งครั้งแรกถูกใจสุดๆเลยค่ะ\nพกพาง่ายชาร์ตแบตแปปเดียวเต็มสีดำสวยสุดๆเลย\nโดยรวมถูกใจมากค่ะ"}, {"Review_Name": "โดย 8***5ตรวจสอบว่ามีการสั่งซื้อแล้ว", "Rating_Time": "09 พ.ค. 2022", "Comment": "ส่งของมาเร็ว แพ็คมาดี ใช้งานง่าย"}, {"Review_Name": "โดย 8***8ตรวจสอบว่ามีการสั่งซื้อแล้ว", "Rating_Time": "09 พ.ค. 2022", "Comment": "แนะนำเลยค่ะ พกพาสะดวก น่ารัก คุณภาพเยี่ยม ❤️❤️❤️"}, {"Review_Name": "โดย ศศิญา ไ.ตรวจสอบว่ามีการสั่งซื้อแล้ว", "Rating_Time": "09 พ.ค. 2022", "Comment": "กล่องแพ็คมาอย่างดี มีกันกระแทก แพ็คเก็จดีงาม ถูกใจสุดๆๆๆๆๆๆๆๆๆๆๆๆๆๆๆ"}, {"Review_Name": "โดย PomPam😽🐾ตรวจสอบว่ามีการสั่งซื้อแล้ว", "Rating_Time": "14 พ.ค. 2022", "Comment": "ได้รับสินค้าเรียบร้อยค่ะ ส่งจากจีนแต่ได้ไวมากๆ แพคมาอย่างดีสินค ...

# %%
with open('lazada_sample_test.json', 'w' , encoding="utf-8") as f:
    f.write(json_string)
